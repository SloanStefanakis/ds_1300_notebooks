# %%
import pandas as pd

# %%
nba20 = pd.read_csv('../work/NBA Data 1999-2021/2020.csv',delimiter=",")

# %%
nba20.sort_values(by='WS',ascending=False)
# Out:
#       Rk                           Player Pos  Age   Tm   G    MP   PER  \
# 261  262           Nikola Jokić\jokicni01   C   25  DEN  72  2488  31.3
# 178  179            Rudy Gobert\goberru01   C   28  UTA  71  2187  23.5
# 296  297         Damian Lillard\lillada01  PG   30  POR  67  2398  25.6
# 11    12  Giannis Antetokounmpo\antetgi01  PF   26  MIL  61  2013  29.2
# 83    84           Jimmy Butler\butleji01  SF   31  MIA  52  1745  26.5
# ..   ...                              ...  ..  ...  ...  ..   ...   ...
# 308  309           Théo Maledon\maledth01  PG   19  OKC  65  1778   8.2
# 196  197               Josh Hall\halljo01  SF   20  OKC  21   336   1.0
# 36    37          Darius Bazley\bazleda01  PF   20  OKC  55  1714   9.7
# 212  213          Killian Hayes\hayeski01  PG   19  DET  26   670   5.3
# 405  406     Aleksej Pokusevski\pokusal01  PF   19  OKC  45  1090   6.1
#
#        TS%   3PAr  ...  Unnamed: 19   OWS  DWS    WS  WS/48  Unnamed: 24  \
# ...

# %%
nba20['Player'][0].split('\\')[0]
# Out:
# 'Precious Achiuwa'

# %%
nba20['Name'] = nba20['Player'].apply(lambda x: x.split('\\')[0])

# %%
nba20.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'Unnamed: 19', 'OWS', 'DWS', 'WS', 'WS/48', 'Unnamed: 24', 'OBPM',
#        'DBPM', 'BPM', 'VORP', 'Name'],
#       dtype='object')

# %%
nba20r=nba20[[ 'Name', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
       'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
       'Unnamed: 19', 'OWS', 'DWS', 'WS', 'WS/48', 'Unnamed: 24', 'OBPM',
       'DBPM', 'BPM', 'VORP']]

# %%
nba20r
# Out:
#                   Name    Pos  Age   Tm   G    MP   PER    TS%   3PAr    FTr  \
# 0     Precious Achiuwa     PF   21  MIA  61   737  14.2  0.550  0.004  0.482
# 1         Jaylen Adams     PG   24  MIL   7    18  -6.5  0.125  0.250  0.000
# 2         Steven Adams      C   27  NOP  58  1605  15.1  0.596  0.010  0.438
# 3          Bam Adebayo      C   23  MIA  64  2143  22.7  0.626  0.010  0.443
# 4    LaMarcus Aldridge      C   35  TOT  26   674  15.7  0.556  0.270  0.159
# ..                 ...    ...  ...  ...  ..   ...   ...    ...    ...    ...
# 535       Delon Wright  SG-PG   28  TOT  63  1748  16.3  0.562  0.332  0.243
# 536     Thaddeus Young     PF   32  CHI  68  1652  20.3  0.578  0.068  0.171
# 537         Trae Young     PG   22  ATL  63  2125  23.0  0.589  0.357  0.491
# 538        Cody Zeller      C   28  CHO  48  1005  18.2  0.599  0.086  0.367
# 539        Ivica Zubac      C   23  LAC  72  1609  19.1  0.693  0.010  0.434
#
# ...

# %% [raw]
# append

# %%
nba20['Year'] = '2020'

# %%
nba20
# Out:
#       Rk                       Player    Pos  Age   Tm   G    MP   PER    TS%  \
# 0      1   Precious Achiuwa\achiupr01     PF   21  MIA  61   737  14.2  0.550
# 1      2       Jaylen Adams\adamsja01     PG   24  MIL   7    18  -6.5  0.125
# 2      3       Steven Adams\adamsst01      C   27  NOP  58  1605  15.1  0.596
# 3      4        Bam Adebayo\adebaba01      C   23  MIA  64  2143  22.7  0.626
# 4      5  LaMarcus Aldridge\aldrila01      C   35  TOT  26   674  15.7  0.556
# ..   ...                          ...    ...  ...  ...  ..   ...   ...    ...
# 535  536       Delon Wright\wrighde01  SG-PG   28  TOT  63  1748  16.3  0.562
# 536  537     Thaddeus Young\youngth01     PF   32  CHI  68  1652  20.3  0.578
# 537  538         Trae Young\youngtr01     PG   22  ATL  63  2125  23.0  0.589
# 538  539        Cody Zeller\zelleco01      C   28  CHO  48  1005  18.2  0.599
# 539  540        Ivica Zubac\zubaciv01      C   23  LAC  72  1609  19.1  0.693
#
# ...

# %% [markdown]
# import glob
# import pandas as pd
#
# files = glob.glob('*.csv')
#
# combined=pd.DataFrame()
#
# for f in files:
#     ff = pd.read_csv(f)
#     ff['FileName'] = f
#     combined=combined.append(ff)
# combined = combined.reset_index(drop=True)
#
# combined

# %%
mvp = pd.read_csv('../work/NBA Data 1999-2021/MVPList.csv',delimiter=",")
mvp.drop(columns=["Unnamed: 19"], axis=1)
mvp
# Out:
#     Year                 Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0   2019  Giannis Antetokounmpo  PF   25  MIL  63  1917  31.9  0.613  0.237
# 1   2018  Giannis Antetokounmpo  PF   24  MIL  72  2358  30.9  0.644  0.163
# 2   2017           James Harden  SG   28  HOU  72  2551  29.8  0.619  0.498
# 3   2016      Russell Westbrook  PG   28  OKC  81  2802  30.6  0.554  0.300
# 4   2015          Stephen Curry  PG   27  GSW  79  2700  31.5  0.669  0.554
# 5   2014          Stephen Curry  PG   26  GSW  80  2613  28.0  0.638  0.482
# 6   2013           Kevin Durant  SF   25  OKC  81  3122  29.8  0.635  0.291
# 7   2012           LeBron James  PF   28  MIA  76  2877  31.6  0.640  0.188
# 8   2011           LeBron James  SF   27  MIA  62  2326  30.7  0.605  0.127
# 9   2010           Derrick Rose  PG   22  CHI  81  3026  23.5  0.550  0.241
# 10  2009           LeBron James  SF   25  CLE  76  2966  31.1  0.604  0.253
# ...

# %%
import matplotlib as plt
# %config InlineBackend.figure_format ='retina' #This makes your plot clearer


plot = mvp[['VORP','PER','WS']].plot(kind='bar',figsize=(10,4),color=('blue','red','black'))
plot.set_xticklabels(mvp['Player']);

# %%
test = mvp.sort_values(by='PER', ascending=False)
test1 = mvp.sort_values(by='VORP')
test2 = mvp.sort_values(by='Year')
test3 = (mvp['PER']+mvp['VORP']+mvp['WS'])/3

# %%
test
# Out:
#     Year                 Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0   2019  Giannis Antetokounmpo  PF   25  MIL  63  1917  31.9  0.613  0.237
# 11  2008           LeBron James  SF   24  CLE  81  3054  31.7  0.591  0.238
# 7   2012           LeBron James  PF   28  MIA  76  2877  31.6  0.640  0.188
# 4   2015          Stephen Curry  PG   27  GSW  79  2700  31.5  0.669  0.554
# 10  2009           LeBron James  SF   25  CLE  76  2966  31.1  0.604  0.253
# 1   2018  Giannis Antetokounmpo  PF   24  MIL  72  2358  30.9  0.644  0.163
# 8   2011           LeBron James  SF   27  MIA  62  2326  30.7  0.605  0.127
# 3   2016      Russell Westbrook  PG   28  OKC  81  2802  30.6  0.554  0.300
# 20  1999       Shaquille O'Neal   C   27  LAL  79  3163  30.6  0.578  0.001
# 6   2013           Kevin Durant  SF   25  OKC  81  3122  29.8  0.635  0.291
# 2   2017           James Harden  SG   28  HOU  72  2551  29.8  0.619  0.498
# ...

# %%
y = mvp['PER']
x = test2['Year']

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data for plotting

fig, ax = plt.subplots()
ax.plot(x, y)

ax.set(xlabel='Year', ylabel='PER',
       title='PER Since 1999s MVP')
ax.grid()

fig.savefig("PERyear.png")
plt.show()

# %% [raw]
# #Changing Player Name/Adding UID (Separating the Player column)
# R20['UID'] = R20['Player'].apply(lambda x: x.split('\\')[1])
# R20
# #Changing Player Name/Adding UID (Separating the Player column)
# R20['UID'] = R20['Player'].apply(lambda x: x.split('\\')[1])
# R20
#
# #Changing Player Name/Adding UID (Separating the Player column)
# R20['UID'] = R20['Player'].apply(lambda x: x.split('\\')[1])
# R20
# Radv20 = pd.merge(R20,Adv20, left_on="UID", right_on="UID", how = 'inner')
# Radv20

# %% [markdown]
#  df = pd.read_csv('C:/Users/sloan/Project/MVPList.csv')
#
# # df1 = df.drop(['Unnamed: 19','Unnamed: 24'], axis=1)
#
# # # df1.to_csv('C:/Users/sloan/Project/NewMVPList.csv')
#
# # print(df1.head())
#
# df = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/1999.csv')
# df1 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2000.csv')
# df2 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2001.csv')
# df3 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2002.csv')
# df4 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2003.csv')
# df5 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2004.csv')
# df6 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2005.csv')
# df7 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2006.csv')
# df8 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2007.csv')
# df9 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2008.csv')
# df10 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2009.csv')
# df11 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2010.csv')
# df12 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2011.csv')
# df13 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2012.csv')
# df14 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2013.csv')
# df15 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2014.csv')
# df16 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2015.csv')
# df17 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2016.csv')
# df18 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2017.csv')
# df19 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2018.csv')
# df20 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2019.csv')
# df21 = pd.read_csv('ds_1300_notebooks/work/NBA Data 1999-2021/2020.csv')
# together_df = pd.concat([df,df1,df2,df3,df4,df5,df6,df7.df8.df9.df10,df11,df12.df13,df14,df15,df16,df17,df18,df19,df20,df21], axis = 0)

# %%
test2 = test2.plot.scatter(x='PER',
                      y='VORP',
                      c='DarkBlue')

# %%
#Importing and combining multiple csv files 
#import glob
#import pandas as pd
#
#files = glob.glob('*.csv')
#
#combined=pd.DataFrame()
#
#for f in files:
#    ff = pd.read_csv(f)
#    ff['FileName'] = f
#    combined=combined.append(ff)
#combined = combined.reset_index(drop=True)
#
#combined
